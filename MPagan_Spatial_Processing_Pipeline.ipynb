# %% [markdown]
# # Spatial Cluster Analysis Pre-Processing Pipeline
# ## SOCI 20519 Final Research Project
# ### Michelangelo Pagan

# %% [markdown]
# ## Step 1: Loading the US Hospitals Shapefile and Selecting for Chicago Hospitals

# %%
import geopandas as gpd

hospitals = gpd.read_file("Hospitals/Hospitals.shp")
hospitals.head(2)
# Out:
#    OBJECTID          ID                       NAME  \
# 0      8237  0001336420           ANDALUSIA HEALTH
# 1      8238  0001535611  ATHENS LIMESTONE HOSPITAL
#
#                                     ADDRESS       CITY STATE    ZIP  \
# 0  849 SOUTH THREE NOTCH STREET, PO BOX 760  ANDALUSIA    AL  36420
# 1                    700 WEST MARKET STREET     ATHENS    AL  35611
#
#             ZIP4       TELEPHONE                TYPE  ...  \
# 0  NOT AVAILABLE  (334) 222-8466  GENERAL ACUTE CARE  ...
# 1  NOT AVAILABLE  (256) 262-6468  GENERAL ACUTE CARE  ...
#
#                                     WEBSITE  STATE_ID       ALT_NAME ST_FIPS  \
# 0  http://www.andalusiaregionalhospital.com     H2001  NOT AVAILABLE      01
# 1    http://www.athenslimestonehospital.com     H4201  NOT AVAILABLE      01
#
#          OWNER  TTL_STAFF  BEDS     TRAUMA HELIPAD  \
# 0  PROPRIETARY       -999    88  LEVEL III       Y
# 1  PROPRIETARY       -999    71  LEVEL III       N
#
#                            geometry
# 0  POINT (-9628529.163 3671223.674)
# 1  POINT (-9682392.001 4137299.549)
#
# [2 rows x 33 columns]

# %%
chicago_hospitals = hospitals.loc[hospitals.CITY == 'CHICAGO']
chicago_hospitals.head(5)
# Out:
#       OBJECTID          ID                                               NAME  \
# 1821     10058  0097460611  ANN AND ROBERT H LURIE CHILDREN'S HOSPITAL OF ...
# 1823     10060  0000260640             AURORA CHICAGO LAKESHORE HOSPITAL, LLC
# 1848     10085  0096360624                        GARFIELD PARK HOSPITAL, LLC
# 1862     10099  0006660629                                HOLY CROSS HOSPITAL
# 1867     10104  0010060622                               HUMBOLDT PARK HEALTH
#
#                                   ADDRESS     CITY STATE    ZIP  \
# 1821  225 EAST CHICAGO AVENUE, PO BOX 140  CHICAGO    IL  60611
# 1823                  4840 N MARINE DRIVE  CHICAGO    IL  60640
# 1848                   520 N RIDGEWAY AVE  CHICAGO    IL  60624
# 1862                       2701 W 68TH ST  CHICAGO    IL  60629
# 1867                 1044 N FRANCISCO AVE  CHICAGO    IL  60622
#
#                ZIP4       TELEPHONE                TYPE  ...  \
# 1821  NOT AVAILABLE  (312) 227-4000            CHILDREN  ...
# 1823  NOT AVAILABLE  (773) 878-9700         PSYCHIATRIC  ...
# 1848  NOT AVAILABLE  (773) 265-3700         PSYCHIATRIC  ...
# 1862  NOT AVAILABLE  (773) 884-9000  GENERAL ACUTE CARE  ...
# 1867  NOT AVAILABLE  (773) 292-8200  GENERAL ACUTE CARE  ...
#
#                                         WEBSITE  STATE_ID  \
# 1821                              NOT AVAILABLE   0005843
# 1823  https://www.chicagolakeshorehospital.com/   0005207
# 1848          https://garfieldparkhospital.com/   0005918
# 1862                              NOT AVAILABLE   0000992
# 1867                              NOT AVAILABLE   0001727
#
#                                ALT_NAME ST_FIPS          OWNER  TTL_STAFF  \
# 1821                      NOT AVAILABLE      17  NOT AVAILABLE       -999
# 1823  AURORA CHICAGO LAKESHORE HOSPITAL      17    PROPRIETARY       -999
# 1848             GARFIELD PARK HOSPITAL      17  NOT AVAILABLE       -999
# 1862                      NOT AVAILABLE      17    PROPRIETARY       -999
# 1867                      NOT AVAILABLE      17     NON-PROFIT       -999
#
#       BEDS             TRAUMA HELIPAD                          geometry
# 1821   364  LEVEL I PEDIATRIC       Y  POINT (-9754005.088 5145480.827)
# 1823   161      NOT AVAILABLE       N  POINT (-9757220.163 5156531.459)
# 1848    88      NOT AVAILABLE       N  POINT (-9764966.085 5144622.643)
# 1862   248      NOT AVAILABLE       N  POINT (-9761871.125 5126500.027)
# 1867   210      NOT AVAILABLE       N  POINT (-9762618.652 5146131.304)
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Step 2: Manually Assigining Academic Status and Community Area # To Hospitals

# %%
hospital_academic_status = {
    "ANN AND ROBERT H LURIE CHILDREN'S HOSPITAL OF CHICAGO": 1,  # Affiliated with Northwestern
    "AURORA CHICAGO LAKESHORE HOSPITAL, LLC": 0,
    "GARFIELD PARK HOSPITAL, LLC": 0,
    "HOLY CROSS HOSPITAL": 0,
    "HUMBOLDT PARK HEALTH": 0,
    "INSIGHT HOSPITAL AND MEDICAL CENTER": 0,
    "JACKSON PARK HOSPITAL": 0,
    "JOHN H. STROGER JR. HOSPITAL OF COOK COUNTY": 1,  # Teaching hospital, Cook County
    "KINDRED CHICAGO NORTHLAKE, LLC": 0,
    "LA RABIDA CHILDREN'S HOSPITAL": 0,
    "LORETTO HOSPITAL": 0,
    "MT. SINAI HOSPITAL MEDICAL CENTER": 1,  # Affiliated with Sinai Chicago, some academic programs
    "NORTHWESTERN MEMORIAL HOSPITAL": 1,  # Major academic hospital (Feinberg)
    "PIPELINE - WEISS MEMORIAL HOSPITAL, LLC": 0,
    "PRESENCE CHICAGO HOSPITALS NETWORK": 0,
    "PRESENCE ST MARY AND ELIZABETH": 0,
    "PROVIDENT HOSPITAL OF COOK COUNTY": 1,  # Teaching hospital (Cook County)
    "REHABILITATION INSTITUTE OF CHICAGO": 1,  # Now Shirley Ryan AbilityLab, research-focused
    "RML HEALTH PROVIDERS LIMITED PARTNERSHIP": 0,
    "ROSELAND COMMUNITY HOSPITAL": 0,
    "RUSH UNIVERSITY MEDICAL CENTER": 1,  # Rush University teaching hospital
    "SAINT ANTHONY HOSPITAL": 0,
    "SCHWAB REHABILITATION HOSPITAL AND CARE NETWORK": 0,
    "SHRINERS HOSPITAL FOR CHILDREN - CHICAGO": 0,
    "SOUTH SHORE HOSPITAL": 0,
    "ST. BERNARD HOSPITAL": 0,
    "SWEDISH COVENANT HEALTH": 0,
    "THOREK MEMORIAL HOSPITAL": 0,
    "UHS HARTGROVE HOSPITAL": 0,
    "UNIVERSITY OF ILLINOIS HOSPITAL AT CHICAGO": 1,  # UIC Medical School Affiliated
    "JESSE BROWN DEPARTMENT OF VETERANS AFFAIRS MEDICAL CENTER": 1,  # UIC-affiliated VA
    "SACRED HEART HOSPITAL": 0,
    "KINDRED CHICAGO CENTRAL HOSPITAL": 0,
    "UI HEALTH": 1,  # Academic medical center
    "UCHICAGO MEDICINE": 1,  # Major academic hospital (Pritzker)
    "MOUNT SINAI HOSPITAL": 1,  # Affiliated with Sinai Chicago, teaching programs
    "COMMUNITY FIRST MEDICAL CENTER": 0,
    "ASCENSION SAINTS MARY AND ELIZABETH": 0,
    "ASCENSION RESURRECTION": 0,
    "ADVOCATE ILLINOIS MASONIC MEDICAL CENTER": 1,  # Some affiliations with UIC
    "ADVOCATE TRINITY HOSPITAL": 0,
    "ASCENSION SAINT JOSEPH - CHICAGO": 0
}

hospital_CA_number = {
    "ANN AND ROBERT H LURIE CHILDREN'S HOSPITAL OF CHICAGO": 8, 
    "AURORA CHICAGO LAKESHORE HOSPITAL, LLC": 3,
    "GARFIELD PARK HOSPITAL, LLC": 23,
    "HOLY CROSS HOSPITAL": 66,
    "HUMBOLDT PARK HEALTH": 24,
    "INSIGHT HOSPITAL AND MEDICAL CENTER": 33,
    "JACKSON PARK HOSPITAL": 43,
    "JOHN H. STROGER JR. HOSPITAL OF COOK COUNTY": 28,  
    "KINDRED CHICAGO NORTHLAKE, LLC": 4,
    "LA RABIDA CHILDREN'S HOSPITAL": 42,
    "LORETTO HOSPITAL": 25,
    "MT. SINAI HOSPITAL MEDICAL CENTER": 29, 
    "NORTHWESTERN MEMORIAL HOSPITAL": 8,  
    "PIPELINE - WEISS MEMORIAL HOSPITAL, LLC": 3,
    "PRESENCE CHICAGO HOSPITALS NETWORK": 10,
    "PRESENCE ST MARY AND ELIZABETH": 24,
    "PROVIDENT HOSPITAL OF COOK COUNTY": 38, 
    "REHABILITATION INSTITUTE OF CHICAGO": 8, 
    "RML HEALTH PROVIDERS LIMITED PARTNERSHIP": 27,
    "ROSELAND COMMUNITY HOSPITAL": 49,
    "RUSH UNIVERSITY MEDICAL CENTER": 28, 
    "SAINT ANTHONY HOSPITAL": 30,
    "SCHWAB REHABILITATION HOSPITAL AND CARE NETWORK": 29,
    "SHRINERS HOSPITAL FOR CHILDREN - CHICAGO": 18,
    "SOUTH SHORE HOSPITAL": 46,
    "ST. BERNARD HOSPITAL": 68,
    "SWEDISH COVENANT HEALTH": 4,
    "THOREK MEMORIAL HOSPITAL": 3,
    "UHS HARTGROVE HOSPITAL": 25,
    "UNIVERSITY OF ILLINOIS HOSPITAL AT CHICAGO": 28, 
    "JESSE BROWN DEPARTMENT OF VETERANS AFFAIRS MEDICAL CENTER": 28, 
    "SACRED HEART HOSPITAL": 23,
    "KINDRED CHICAGO CENTRAL HOSPITAL": 16,
    "UI HEALTH": 28,  
    "UCHICAGO MEDICINE": 41, 
    "MOUNT SINAI HOSPITAL": 29, 
    "COMMUNITY FIRST MEDICAL CENTER": 15,
    "ASCENSION SAINTS MARY AND ELIZABETH": 24,
    "ASCENSION RESURRECTION": 10,
    "ADVOCATE ILLINOIS MASONIC MEDICAL CENTER": 6, 
    "ADVOCATE TRINITY HOSPITAL": 48,
    "ASCENSION SAINT JOSEPH - CHICAGO": 6
}

import pandas as pd

df_academic_status = pd.DataFrame(
    list(hospital_academic_status.items()), columns=["NAME", "Academic_Status"]
)
df_CA = pd.DataFrame(
    list(hospital_CA_number.items()), columns=["NAME", "CommunityArea"]
)

df_hospitals = chicago_hospitals.merge(df_academic_status, on="NAME", how="left")
df_hospitals_ca = df_hospitals.merge(df_CA, on="NAME", how='left')

df_hospitals_ca.drop(columns = ["ADDRESS", "ZIP4","TELEPHONE", "ST_FIPS", "TTL_STAFF", "COUNTRY", "ALT_NAME", "WEBSITE", "SOURCE", "SOURCEDATE", "VAL_METHOD", "VAL_DATE", "STATE_ID"])
# Out:
#     OBJECTID          ID                                               NAME  \
# 0      10058  0097460611  ANN AND ROBERT H LURIE CHILDREN'S HOSPITAL OF ...
# 1      10060  0000260640             AURORA CHICAGO LAKESHORE HOSPITAL, LLC
# 2      10085  0096360624                        GARFIELD PARK HOSPITAL, LLC
# 3      10099  0006660629                                HOLY CROSS HOSPITAL
# 4      10104  0010060622                               HUMBOLDT PARK HEALTH
# 5      10106  0007660616                INSIGHT HOSPITAL AND MEDICAL CENTER
# 6      10108  0008660649                              JACKSON PARK HOSPITAL
# 7      10111  0006260612        JOHN H. STROGER JR. HOSPITAL OF COOK COUNTY
# 8      10113  0097160618                     KINDRED CHICAGO NORTHLAKE, LLC
# 9      10117  0001360649                      LA RABIDA CHILDREN'S HOSPITAL
# 10     10119  0004160644                                   LORETTO HOSPITAL
# 11     10137  0001060608                  MT. SINAI HOSPITAL MEDICAL CENTER
# 12     10148  0012360611                     NORTHWESTERN MEMORIAL HOSPITAL
# 13     10161  0004060640            PIPELINE - WEISS MEMORIAL HOSPITAL, LLC
# 14     10165  0099460631                 PRESENCE CHICAGO HOSPITALS NETWORK
# 15     10167  0010860657                 PRESENCE CHICAGO HOSPITALS NETWORK
# 16     10168  0099760622                     PRESENCE ST MARY AND ELIZABETH
# 17     10169  0013160615                  PROVIDENT HOSPITAL OF COOK COUNTY
# 18     10171  0196260611                REHABILITATION INSTITUTE OF CHICAGO
# 19     10175  0002060624           RML HEALTH PROVIDERS LIMITED PARTNERSHIP
# 20     10178  0003660628                        ROSELAND COMMUNITY HOSPITAL
# 21     10180  0005960612                     RUSH UNIVERSITY MEDICAL CENTER
# 22     10181  0004860623                             SAINT ANTHONY HOSPITAL
# 23     10188  0002360608    SCHWAB REHABILITATION HOSPITAL AND CARE NETWORK
# 24     10189  0002460635           SHRINERS HOSPITAL FOR CHILDREN - CHICAGO
# 25     10192  0008960617                               SOUTH SHORE HOSPITAL
# 26     10200  0005160621                               ST. BERNARD HOSPITAL
# 27     10208  0005460625                            SWEDISH COVENANT HEALTH
# 28     10214  0005560613                           THOREK MEMORIAL HOSPITAL
# 29     10215  0009760609                           THOREK MEMORIAL HOSPITAL
# 30     10219  0003460644                             UHS HARTGROVE HOSPITAL
# 31     10220  0007360612         UNIVERSITY OF ILLINOIS HOSPITAL AT CHICAGO
# 32     14676  0001860612  JESSE BROWN DEPARTMENT OF VETERANS AFFAIRS MED...
# 33     15273  0001760611                REHABILITATION INSTITUTE OF CHICAGO
# 34     15706  0007460624                              SACRED HEART HOSPITAL
# 35     15751  0003160641                   KINDRED CHICAGO CENTRAL HOSPITAL
# 36     16442  0196785257                                          UI HEALTH
# 37     16446  0196785256                                  UCHICAGO MEDICINE
# 38     16449  0196785249                               MOUNT SINAI HOSPITAL
# 39     16455  0196785239                     COMMUNITY FIRST MEDICAL CENTER
# 40     16456  0196785236                ASCENSION SAINTS MARY AND ELIZABETH
# 41     16473  0196785231                             ASCENSION RESURRECTION
# 42     16484  0196785227           ADVOCATE ILLINOIS MASONIC MEDICAL CENTER
# 43     16487  0196785228                          ADVOCATE TRINITY HOSPITAL
# 44     16555  0196785233                   ASCENSION SAINT JOSEPH - CHICAGO
#
#        CITY STATE    ZIP                TYPE  STATUS  POPULATION COUNTY  ...  \
# 0   CHICAGO    IL  60611            CHILDREN    OPEN         364   COOK  ...
# 1   CHICAGO    IL  60640         PSYCHIATRIC    OPEN         161   COOK  ...
# 2   CHICAGO    IL  60624         PSYCHIATRIC    OPEN          88   COOK  ...
# 3   CHICAGO    IL  60629  GENERAL ACUTE CARE    OPEN         248   COOK  ...
# 4   CHICAGO    IL  60622  GENERAL ACUTE CARE    OPEN         210   COOK  ...
# 5   CHICAGO    IL  60616  GENERAL ACUTE CARE    OPEN         412   COOK  ...
# 6   CHICAGO    IL  60649  GENERAL ACUTE CARE    OPEN         239   COOK  ...
# 7   CHICAGO    IL  60612  GENERAL ACUTE CARE    OPEN         450   COOK  ...
# 8   CHICAGO    IL  60618      LONG TERM CARE    OPEN          94   COOK  ...
# 9   CHICAGO    IL  60649            CHILDREN    OPEN          49   COOK  ...
# 10  CHICAGO    IL  60644  GENERAL ACUTE CARE    OPEN         177   COOK  ...
# 11  CHICAGO    IL  60608  GENERAL ACUTE CARE    OPEN         288   COOK  ...
# 12  CHICAGO    IL  60611  GENERAL ACUTE CARE    OPEN         943   COOK  ...
# 13  CHICAGO    IL  60640  GENERAL ACUTE CARE    OPEN         236   COOK  ...
# 14  CHICAGO    IL  60631  GENERAL ACUTE CARE    OPEN         305   COOK  ...
# 15  CHICAGO    IL  60657  GENERAL ACUTE CARE    OPEN         338   COOK  ...
# 16  CHICAGO    IL  60622  GENERAL ACUTE CARE    OPEN         455   COOK  ...
# 17  CHICAGO    IL  60615  GENERAL ACUTE CARE    OPEN          48   COOK  ...
# 18  CHICAGO    IL  60611      REHABILITATION    OPEN         242   COOK  ...
# 19  CHICAGO    IL  60624      LONG TERM CARE    OPEN          68   COOK  ...
# 20  CHICAGO    IL  60628  GENERAL ACUTE CARE    OPEN         134   COOK  ...
# 21  CHICAGO    IL  60612  GENERAL ACUTE CARE    OPEN         727   COOK  ...
# 22  CHICAGO    IL  60623  GENERAL ACUTE CARE    OPEN         151   COOK  ...
# 23  CHICAGO    IL  60608      REHABILITATION    OPEN         102   COOK  ...
# 24  CHICAGO    IL  60707            CHILDREN    OPEN          60   COOK  ...
# 25  CHICAGO    IL  60617  GENERAL ACUTE CARE    OPEN         137   COOK  ...
# 26  CHICAGO    IL  60621  GENERAL ACUTE CARE    OPEN         174   COOK  ...
# 27  CHICAGO    IL  60625  GENERAL ACUTE CARE    OPEN         292   COOK  ...
# 28  CHICAGO    IL  60613  GENERAL ACUTE CARE    OPEN         218   COOK  ...
# 29  CHICAGO    IL  60640  GENERAL ACUTE CARE    OPEN         145   COOK  ...
# 30  CHICAGO    IL  60644         PSYCHIATRIC    OPEN         160   COOK  ...
# 31  CHICAGO    IL  60612  GENERAL ACUTE CARE    OPEN         485   COOK  ...
# 32  CHICAGO    IL  60612            MILITARY    OPEN         240   COOK  ...
# 33  CHICAGO    IL  60611      REHABILITATION    OPEN         182   COOK  ...
# 34  CHICAGO    IL  60624  GENERAL ACUTE CARE  CLOSED         119   COOK  ...
# 35  CHICAGO    IL  60641      LONG TERM CARE    OPEN          54   COOK  ...
# 36  CHICAGO    IL  60612  GENERAL ACUTE CARE    OPEN         450   COOK  ...
# 37  CHICAGO    IL  60637  GENERAL ACUTE CARE    OPEN         862   COOK  ...
# 38  CHICAGO    IL  60608  GENERAL ACUTE CARE    OPEN         288   COOK  ...
# 39  CHICAGO    IL  60634  GENERAL ACUTE CARE    OPEN         296   COOK  ...
# 40  CHICAGO    IL  60622  GENERAL ACUTE CARE    OPEN         469   COOK  ...
# 41  CHICAGO    IL  60631  GENERAL ACUTE CARE    OPEN         305   COOK  ...
# 42  CHICAGO    IL  60657  GENERAL ACUTE CARE    OPEN         326   COOK  ...
# 43  CHICAGO    IL  60617  GENERAL ACUTE CARE    OPEN         205   COOK  ...
# 44  CHICAGO    IL  60657  GENERAL ACUTE CARE    OPEN         326   COOK  ...
#
#     LONGITUDE  NAICS_CODE                                         NAICS_DESC  \
# 0  -87.621719      622110                      CHILDREN'S HOSPITALS, GENERAL
# 1  -87.650600      622210          PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS
# 2  -87.720183      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 3  -87.692380      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 4  -87.699095      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 5  -87.621492      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 6  -87.585235      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 7  -87.674398      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 8  -87.693297      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 9  -87.571312      622110                      CHILDREN'S HOSPITALS, GENERAL
# 10 -87.764089      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 11 -87.694339      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 12 -87.621024      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 13 -87.649627      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 14 -87.813566      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 15 -87.637069      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 16 -87.686310      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 17 -87.613324      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 18 -87.618438      622310  REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, D...
# 19 -87.712272      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 20 -87.626010      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 21 -87.668910      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 22 -87.698277      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 23 -87.695317      622310  REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, D...
# 24 -87.793423      622110                      CHILDREN'S HOSPITALS, GENERAL
# 25 -87.568997      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 26 -87.633601      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 27 -87.699466      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 28 -87.651621      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 29 -87.670743      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 30 -87.767464      622210          PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS
# 31 -87.670515      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 32 -87.677041      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 33 -87.618335      622310  REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, D...
# 34 -87.707878      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 35 -87.728644      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 36 -87.670628      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 37 -87.603773      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 38 -87.694792      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 39 -87.767743      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 40 -87.683614      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 41 -87.814331      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 42 -87.651175      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 43 -87.567475      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 44 -87.637180      622110             GENERAL MEDICAL AND SURGICAL HOSPITALS
#
#                    OWNER BEDS                            TRAUMA  HELIPAD  \
# 0          NOT AVAILABLE  364                 LEVEL I PEDIATRIC        Y
# 1            PROPRIETARY  161                     NOT AVAILABLE        N
# 2          NOT AVAILABLE   88                     NOT AVAILABLE        N
# 3            PROPRIETARY  248                     NOT AVAILABLE        N
# 4             NON-PROFIT  210                     NOT AVAILABLE        N
# 5             NON-PROFIT  412                     NOT AVAILABLE        N
# 6             NON-PROFIT  239                     NOT AVAILABLE        N
# 7     GOVERNMENT - LOCAL  450  LEVEL I ADULT, LEVEL I PEDIATRIC        Y
# 8          NOT AVAILABLE   94                     NOT AVAILABLE        N
# 9             NON-PROFIT   49                     NOT AVAILABLE        N
# 10            NON-PROFIT  177                     NOT AVAILABLE        N
# 11            NON-PROFIT  288                           LEVEL I        N
# 12            NON-PROFIT  943                           LEVEL I        N
# 13           PROPRIETARY  236                     NOT AVAILABLE        N
# 14         NOT AVAILABLE  305                     NOT AVAILABLE        Y
# 15            NON-PROFIT  338                     NOT AVAILABLE        N
# 16            NON-PROFIT  455                     NOT AVAILABLE        N
# 17    GOVERNMENT - LOCAL   48                     NOT AVAILABLE        N
# 18            NON-PROFIT  242                     NOT AVAILABLE        N
# 19            NON-PROFIT   68                     NOT AVAILABLE        N
# 20            NON-PROFIT  134                     NOT AVAILABLE        N
# 21            NON-PROFIT  727                     NOT AVAILABLE        Y
# 22            NON-PROFIT  151                     NOT AVAILABLE        N
# 23            NON-PROFIT  102                     NOT AVAILABLE        N
# 24            NON-PROFIT   60                     NOT AVAILABLE        N
# 25            NON-PROFIT  137                     NOT AVAILABLE        N
# 26            NON-PROFIT  174                     NOT AVAILABLE        N
# 27            NON-PROFIT  292                     NOT AVAILABLE        N
# 28            NON-PROFIT  218                     NOT AVAILABLE        N
# 29            NON-PROFIT  145                     NOT AVAILABLE        N
# 30           PROPRIETARY  160                     NOT AVAILABLE        N
# 31    GOVERNMENT - STATE  485                     NOT AVAILABLE        N
# 32  GOVERNMENT - FEDERAL  240                     NOT AVAILABLE        N
# 33            NON-PROFIT  182                     NOT AVAILABLE        N
# 34           PROPRIETARY  119                     NOT AVAILABLE        N
# 35           PROPRIETARY   54                     NOT AVAILABLE        N
# 36    GOVERNMENT - STATE  450                     NOT AVAILABLE        N
# 37            NON-PROFIT  862                     NOT AVAILABLE        Y
# 38            NON-PROFIT  288             Level I Trauma Center        N
# 39            NON-PROFIT  296                     NOT AVAILABLE        N
# 40            NON-PROFIT  469                     NOT AVAILABLE        Y
# 41            NON-PROFIT  305                     NOT AVAILABLE        Y
# 42            NON-PROFIT  326             Level I Trauma Center        N
# 43            NON-PROFIT  205                     NOT AVAILABLE        N
# 44            NON-PROFIT  326                     NOT AVAILABLE        N
#
#                             geometry Academic_Status CommunityArea
# 0   POINT (-9754005.088 5145480.827)               1             8
# 1   POINT (-9757220.163 5156531.459)               0             3
# 2   POINT (-9764966.085 5144622.643)               0            23
# 3   POINT (-9761871.125 5126500.027)               0            66
# 4   POINT (-9762618.652 5146131.304)               0            24
# 5   POINT (-9753979.827 5138071.767)               0            33
# 6   POINT (-9749943.768 5124757.466)               0            43
# 7   POINT (-9759869.392 5141874.969)               1            28
# 8    POINT (-9761973.188 5155214.46)               0             4
# 9   POINT (-9748393.908 5127677.225)               0            42
# 10   POINT (-9769853.658 5141843.53)               0            25
# 11  POINT (-9762089.116 5140152.166)               1            29
# 12  POINT (-9753927.816 5145205.241)               1             8
# 13  POINT (-9757111.825 5155957.888)               0             3
# 14  POINT (-9775361.401 5159113.059)               0            10
# 15  POINT (-9755713.906 5151071.257)               0            10
# 16   POINT (-9761195.39 5147146.249)               0            24
# 17    POINT (-9753070.6 5131466.794)               1            38
# 18  POINT (-9753639.871 5145114.765)               1             8
# 19  POINT (-9764085.461 5142265.163)               0            27
# 20  POINT (-9754482.787 5114998.249)               0            49
# 21    POINT (-9759258.4 5142209.395)               1            28
# 22  POINT (-9762527.535 5139315.896)               0            30
# 23  POINT (-9762197.996 5140374.433)               0            29
# 24   POINT (-9773119.09 5148979.124)               0            18
# 25   POINT (-9748136.142 5123503.55)               0            46
# 26   POINT (-9755327.878 5127841.61)               0            68
# 27  POINT (-9762659.883 5157287.941)               0             4
# 28  POINT (-9757333.844 5154269.338)               0             3
# 29  POINT (-9759462.475 5156948.825)               0             3
# 30  POINT (-9770229.427 5140977.239)               0            25
# 31  POINT (-9759437.129 5141476.407)               1            28
# 32   POINT (-9760163.612 5141636.22)               1            28
# 33  POINT (-9753628.414 5145331.883)               1             8
# 34   POINT (-9763596.37 5144609.132)               0            23
# 35   POINT (-9765907.944 5152032.87)               0            16
# 36  POINT (-9759449.714 5141476.648)               1            28
# 37  POINT (-9752007.404 5129448.134)               1            41
# 38   POINT (-9762139.625 5140199.58)               1            29
# 39   POINT (-9770260.448 5152839.77)               0            15
# 40  POINT (-9760895.317 5146415.426)               0            24
# 41  POINT (-9775446.648 5159182.082)               0            10
# 42  POINT (-9757284.213 5151512.942)               1             6
# 43  POINT (-9747966.766 5120128.323)               0            48
# 44  POINT (-9755726.216 5151077.572)               0             6
#
# [45 rows x 22 columns]

# %% [markdown]
# ## Step 3: Saving Updated Shapefiles (with Separate Files for Academic and Non-Academic)

# %%
df_hospitals.to_file("/Users/michelangelopagan/Desktop/DATA/Data20519/Spatial Analysis RQ Data/Filtered/ChiHospitals.shp")

hospitals_academic = df_hospitals_ca.loc[df_hospitals_ca.Academic_Status == 1]
hospitals_nonacademic = df_hospitals_ca.loc[df_hospitals_ca.Academic_Status == 0]

hospitals_academic.to_file("/Users/michelangelopagan/Desktop/DATA/Data20519/Spatial Analysis RQ Data/Filtered/ChiAcademicHospitals.shp")
hospitals_nonacademic.to_file("/Users/michelangelopagan/Desktop/DATA/Data20519/Spatial Analysis RQ Data/Filtered/ChiNonAcademicHospitals.shp")

# %% [markdown]
# ## Step 4: Creating EPA Metrics for Academic and Non-Academic Hospitals in Chicago

# %%
academic_counts = df_hospitals["Academic_Status"].value_counts()
total_hospitals = len(df_hospitals)

print("Hospital Count by Academic Status:")
for status, count in academic_counts.items():
    percentage = (count / total_hospitals) * 100
    print(f"{status}: {count} hospitals ({percentage:.2f}%)")

# Sum the total number of beds in academic and non-academic hospitals
bed_sums = df_hospitals.groupby("Academic_Status")["BEDS"].sum()

total_beds = bed_sums.sum()

print("\nTotal Beds by Academic Status:")
for status, bed_count in bed_sums.items():
    percentage = (bed_count / total_beds) * 100
    print(f"{status}: {bed_count} beds ({percentage:.2f}%)")
# Out:
# Hospital Count by Academic Status:
# 0: 31 hospitals (68.89%)
# 1: 14 hospitals (31.11%)
#
# Total Beds by Academic Status:
# 0: 6427 beds (52.16%)
# 1: 5895 beds (47.84%)

# %% [markdown]
# ## Step 5: Mapping Community Areas to Zip Codes Using Census Tract Walk Files and Coverage Ratios

# %% [markdown]
# The files below contain **census tract data** and their 'total_ratio' (in terms of area) in each ZIP code. The tract has census tracts in all the US, which I shrink to just Cook county.

# %%
tract_CA = pd.read_csv("Spatial Analysis RQ Data/Census_Tracts_in_Chicago_Community_Areas.csv")
tract_ZIP = pd.read_csv("Spatial Analysis RQ Data/TRACT_ZIP_032010.csv")

tract_ZIP.head(2)
# Out:
#         TRACT    ZIP  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 0  1001020100  36067   1.000000   1.000000   1.000000   1.000000
# 1  1001020200  36008   0.027254   0.003378   0.027778   0.021773

# %%
cook_tracts = tract_CA.Tract.to_list()

# %%
cook_tract_zip = tract_ZIP[tract_ZIP['TRACT'].isin(cook_tracts)].drop(columns = ["RES_RATIO", "BUS_RATIO", "OTH_RATIO"]).reset_index(drop=True).rename(columns = {"TRACT":"Tract"})
cook_tract_zip.head(2)
# Out:
#          Tract    ZIP  TOT_RATIO
# 0  17031010100  60202     0.0003
# 1  17031010100  60626     0.9997

# %%
tract_CA
# Out:
#            Tract                                       Label  \
# 0    17031010100     Census Tract 101, Cook County, Illinois
# 1    17031010201  Census Tract 102.01, Cook County, Illinois
# 2    17031010202  Census Tract 102.02, Cook County, Illinois
# 3    17031010300     Census Tract 103, Cook County, Illinois
# 4    17031010400     Census Tract 104, Cook County, Illinois
# ..           ...                                         ...
# 789  17031843500    Census Tract 8435, Cook County, Illinois
# 790  17031843600    Census Tract 8436, Cook County, Illinois
# 791  17031843700    Census Tract 8437, Cook County, Illinois
# 792  17031843800    Census Tract 8438, Cook County, Illinois
# 793  17031843900    Census Tract 8439, Cook County, Illinois
#
#      CommunityAreaNumber CommunityAreaName
# 0                      1       Rogers Park
# 1                      1       Rogers Park
# 2                      1       Rogers Park
# 3                      1       Rogers Park
# 4                      1       Rogers Park
# ..                   ...               ...
# 789                   30    South Lawndale
# 790                   38   Grand Boulevard
# 791                    5      North Center
# 792                   61          New City
# 793                   42          Woodlawn
#
# [794 rows x 4 columns]

# %% [markdown]
# Now that I have tract data for Cook County mapped to Community Areas, I can merge the dataframes to include the tract, ZIP it belongs to, ratio within the ZIP, and Community Area Name. This is useful, because we can now take hospital data that is at a ZIP code level, use proportions to assign those into census tracts, and sum them for putting them in Community Areas.

# %%
merged_CA_ZIP_df = cook_tract_zip.merge(tract_CA, on="Tract", how="inner")
merged_CA_ZIP_df.head(2)
# Out:
#          Tract    ZIP  TOT_RATIO                                    Label  \
# 0  17031010100  60202     0.0003  Census Tract 101, Cook County, Illinois
# 1  17031010100  60626     0.9997  Census Tract 101, Cook County, Illinois
#
#    CommunityAreaNumber CommunityAreaName
# 0                    1       Rogers Park
# 1                    1       Rogers Park

# %% [markdown]
# ## Step 6: Integrating Readmission Data for Heart Failure, Pneumonia, and Heart Attacks
# - for the readmission dataframes, the unit is per 100k (by ZIP)
# - for the preventable and non preventable ER hospitalizations, the unit is percentage (by ZIP)

# %%
HA_readmit = pd.read_csv("Spatial Analysis RQ Data/HA_Readmissions.csv", header =1 )
HF_readmit = pd.read_csv("Spatial Analysis RQ Data/HF_Readmissions.csv", header =1 )
non_preventable = pd.read_csv("Spatial Analysis RQ Data/non_preventable.csv", header =1 )
PN_readmit = pd.read_csv("Spatial Analysis RQ Data/PN_readmissions.csv", header =1 )
preventable = pd.read_csv("Spatial Analysis RQ Data/preventable.csv", header =1 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 HA_readmit = pd.read_csv("Spatial Analysis RQ Data/HA_Readmissions.csv", header =1 )
#       2 HF_readmit = pd.read_csv("Spatial Analysis RQ Data/HF_Readmissions.csv", header =1 )
#       3 non_preventable = pd.read_csv("Spatial Analysis RQ Data/non_preventable.csv", header =1 )
#
# NameError: name 'pd' is not defined

# %%
HA_readmit = HA_readmit[HA_readmit["region"].astype(str).str.isdigit()]
HA_readmit = HA_readmit[["region", "value", "date_start", "date_end"]]
chicago_zip_codes = [
    "60601", "60602", "60603", "60604", "60605", "60606", "60607", "60608", "60609", "60610",
    "60611", "60612", "60613", "60614", "60615", "60616", "60617", "60618", "60619", "60620",
    "60621", "60622", "60623", "60624", "60625", "60626", "60628", "60629", "60630", "60631",
    "60632", "60633", "60634", "60636", "60637", "60638", "60639", "60640", "60641", "60642",
    "60643", "60644", "60645", "60646", "60647", "60649", "60651", "60652", "60653", "60654",
    "60655", "60656", "60657", "60659", "60660", "60661", "60664", "60666", "60680", "60681",
    "60690", "60691", "60701", "60706", "60707", "60803", "60804", "60805", "60827"
]

HA_chicago = HA_readmit[HA_readmit["region"].astype(str).isin(chicago_zip_codes)]
HA_chicago = HA_chicago.copy()
HA_chicago.columns = HA_chicago.columns.str.strip()
HA_chicago.loc[:, "value"] = pd.to_numeric(HA_chicago["value"], errors="coerce")
HA_chicago = HA_chicago.dropna(subset=["value"])
HA_chicago["region"] = HA_chicago["region"].astype(str)
HA_chicago_avg = HA_chicago.groupby("region", as_index=False).agg({"value": "mean"})
HA_chicago_avg.rename(columns={"region": "ZIP", "value": "avg_readmission_rate"}, inplace=True)

# %%
def process_readmission_data(df, chicago_zip_codes):
    """
    Cleans and processes a readmission DataFrame to filter only Chicago ZIP codes
    and compute the average readmission rate per ZIP code.

    Parameters:
    df (pd.DataFrame): The raw readmission dataset.
    chicago_zip_codes (list): List of valid Chicago ZIP codes.

    Returns:
    pd.DataFrame: Processed DataFrame with ZIP and avg_readmission_rate.
    """
    df = df[df["region"].astype(str).str.isdigit()]

    df = df[["region", "value", "date_start", "date_end"]]

    df = df[df["region"].astype(str).isin(chicago_zip_codes)].copy()

    df.columns = df.columns.str.strip()

    df.loc[:, "value"] = pd.to_numeric(df["value"], errors="coerce")

    df = df.dropna(subset=["value"])

    df["region"] = df["region"].astype(str)

    df_avg = df.groupby("region", as_index=False).agg({"value": "mean"})

    df_avg.rename(columns={"region": "ZIP", "value": "avg_readmission_per_100k"}, inplace=True)

    return df_avg

chicago_zip_codes = [
    "60601", "60602", "60603", "60604", "60605", "60606", "60607", "60608", "60609", "60610",
    "60611", "60612", "60613", "60614", "60615", "60616", "60617", "60618", "60619", "60620",
    "60621", "60622", "60623", "60624", "60625", "60626", "60628", "60629", "60630", "60631",
    "60632", "60633", "60634", "60636", "60637", "60638", "60639", "60640", "60641", "60642",
    "60643", "60644", "60645", "60646", "60647", "60649", "60651", "60652", "60653", "60654",
    "60655", "60656", "60657", "60659", "60660", "60661", "60664", "60666", "60680", "60681",
    "60690", "60691", "60701", "60706", "60707", "60803", "60804", "60805", "60827"
]

HA_chicago_avg = process_readmission_data(HA_readmit, chicago_zip_codes).rename(columns = {"avg_readmission_per_100k": "avg_HA_readmission_per_100k"})
HF_chicago_avg = process_readmission_data(HF_readmit, chicago_zip_codes).rename(columns = {"avg_readmission_per_100k": "avg_HF_readmission_per_100k"})
non_preventable_avg = process_readmission_data(non_preventable, chicago_zip_codes).rename(columns = {"avg_readmission_per_100k": "non_preventable_em_percent"})
PN_chicago_avg = process_readmission_data(PN_readmit, chicago_zip_codes).rename(columns = {"avg_readmission_per_100k": "avg_PN_readmission_per_100k"})
preventable_avg = process_readmission_data(preventable, chicago_zip_codes).rename(columns = {"avg_readmission_per_100k": "preventable_em_percent"})

# %% [markdown]
# Finding the data frame that includes the largest amount of zip code data to perform left joins:

# %%
largest_df = max(
    [HA_chicago_avg, HF_chicago_avg, non_preventable_avg, PN_chicago_avg, preventable_avg], 
    key=lambda df: df["ZIP"].nunique()
)
largest_df
# Out:
#       ZIP  non_preventable_em_percent
# 0   60601                     13.2450
# 1   60602                     11.2275
# 2   60603                     11.5500
# 3   60604                     10.5575
# 4   60605                     13.2075
# ..    ...                         ...
# 57  60707                     11.9000
# 58  60803                     12.1350
# 59  60804                     10.7725
# 60  60805                     12.1325
# 61  60827                      9.4550
#
# [62 rows x 2 columns]

# %%
merged_df = largest_df.copy()

# Merge each dataset one by one, keeping all ZIPs from the largest DataFrame
merged_df = merged_df.merge(HA_chicago_avg, on="ZIP", how="left")
merged_df = merged_df.merge(HF_chicago_avg, on="ZIP", how="left")
merged_df = merged_df.merge(non_preventable_avg, on="ZIP", how="left")
merged_df = merged_df.merge(PN_chicago_avg, on="ZIP", how="left")
merged_df = merged_df.merge(preventable_avg, on="ZIP", how="left")

# %%
merged_admission_df = merged_df.copy()

# %% [markdown]
# ### We now have these readmission metrics per zip code where data was available. Next step is to go back and merge them with the other DF to start doing the spatial weight .

# %%
merged_admission_df["ZIP"] = [int(x) for x in merged_admission_df["ZIP"]]
merged_admission_df
# Out:
#       ZIP  non_preventable_em_percent_x  avg_HA_readmission_per_100k  \
# 0   60601                       13.2450                          NaN
# 1   60602                       11.2275                          NaN
# 2   60603                       11.5500                          NaN
# 3   60604                       10.5575                          NaN
# 4   60605                       13.2075                          NaN
# ..    ...                           ...                          ...
# 57  60707                       11.9000                       60.280
# 58  60803                       12.1350                          NaN
# 59  60804                       10.7725                       22.375
# 60  60805                       12.1325                          NaN
# 61  60827                        9.4550                          NaN
#
#     avg_HF_readmission_per_100k  non_preventable_em_percent_y  \
# 0                           NaN                       13.2450
# 1                           NaN                       11.2275
# 2                           NaN                       11.5500
# 3                           NaN                       10.5575
# 4                     78.035000                       13.2075
# ..                          ...                           ...
# 57                    97.780000                       11.9000
# 58                   127.823333                       12.1350
# 59                    58.226667                       10.7725
# 60                   162.046667                       12.1325
# 61                   183.583333                        9.4550
#
#     avg_PN_readmission_per_100k  preventable_em_percent
# 0                           NaN                  3.7450
# 1                           NaN                  3.9900
# 2                           NaN                  4.6375
# 3                           NaN                  4.6725
# 4                           NaN                  4.2475
# ..                          ...                     ...
# 57                    42.970000                  5.1375
# 58                          NaN                  5.2500
# 59                    27.436667                  5.2000
# 60                   103.170000                  4.8725
# 61                    52.583333                  7.1400
#
# [62 rows x 7 columns]

# %%
merged_CA_ZIP_df.loc[merged_CA_ZIP_df.ZIP == 60637]
# Out:
#            Tract    ZIP  TOT_RATIO                                     Label  \
# 468  17031400300  60637   0.004902  Census Tract 4003, Cook County, Illinois
# 469  17031400400  60637   1.000000  Census Tract 4004, Cook County, Illinois
# 471  17031400500  60637   0.982784  Census Tract 4005, Cook County, Illinois
# 473  17031400800  60637   0.990352  Census Tract 4008, Cook County, Illinois
# 482  17031411000  60637   0.911901  Census Tract 4110, Cook County, Illinois
# 484  17031411100  60637   0.826358  Census Tract 4111, Cook County, Illinois
# 486  17031411200  60637   0.970884  Census Tract 4112, Cook County, Illinois
# 487  17031420100  60637   1.000000  Census Tract 4201, Cook County, Illinois
# 488  17031420200  60637   1.000000  Census Tract 4202, Cook County, Illinois
# 489  17031420300  60637   1.000000  Census Tract 4203, Cook County, Illinois
# 490  17031420400  60637   1.000000  Census Tract 4204, Cook County, Illinois
# 491  17031420500  60637   1.000000  Census Tract 4205, Cook County, Illinois
# 492  17031420600  60637   1.000000  Census Tract 4206, Cook County, Illinois
# 493  17031420700  60637   1.000000  Census Tract 4207, Cook County, Illinois
# 494  17031420800  60637   1.000000  Census Tract 4208, Cook County, Illinois
# 495  17031421200  60637   1.000000  Census Tract 4212, Cook County, Illinois
# 498  17031430300  60637   0.957308  Census Tract 4303, Cook County, Illinois
# 692  17031690400  60637   0.969409  Census Tract 6904, Cook County, Illinois
# 694  17031690500  60637   0.937229  Census Tract 6905, Cook County, Illinois
#
#      CommunityAreaNumber       CommunityAreaName
# 468                   40         Washington Park
# 469                   40         Washington Park
# 471                   40         Washington Park
# 473                   40         Washington Park
# 482                   41               Hyde Park
# 484                   41               Hyde Park
# 486                   41               Hyde Park
# 487                   42                Woodlawn
# 488                   42                Woodlawn
# 489                   42                Woodlawn
# 490                   42                Woodlawn
# 491                   42                Woodlawn
# 492                   42                Woodlawn
# 493                   42                Woodlawn
# 494                   42                Woodlawn
# 495                   42                Woodlawn
# 498                   43             South Shore
# 692                   69  Greater Grand Crossing
# 694                   69  Greater Grand Crossing

# %%
# Merge ZIP-level readmission data onto Tract-to-Community mapping
weighted_data = merged_CA_ZIP_df.merge(merged_admission_df, on="ZIP", how="left")

# Compute weighted readmission rates by multiplying with TOT_RATIO
for col in [
    "avg_HA_readmission_per_100k", 
    "avg_HF_readmission_per_100k", 
    "avg_PN_readmission_per_100k", 
    "non_preventable_em_percent_x", 
    "preventable_em_percent"
]:
    weighted_data[f"{col}_weighted"] = weighted_data[col] * weighted_data["TOT_RATIO"]

weighted_data
# Out:
#            Tract    ZIP  TOT_RATIO                                     Label  \
# 0    17031010100  60202   0.000300   Census Tract 101, Cook County, Illinois
# 1    17031010100  60626   0.999700   Census Tract 101, Cook County, Illinois
# 2    17031010300  60626   1.000000   Census Tract 103, Cook County, Illinois
# 3    17031010400  60626   0.997992   Census Tract 104, Cook County, Illinois
# 4    17031010400  60660   0.002008   Census Tract 104, Cook County, Illinois
# ..           ...    ...        ...                                       ...
# 752  17031750400  60643   0.108309  Census Tract 7504, Cook County, Illinois
# 753  17031750400  60655   0.891691  Census Tract 7504, Cook County, Illinois
# 754  17031750500  60643   1.000000  Census Tract 7505, Cook County, Illinois
# 755  17031750600  60628   0.043450  Census Tract 7506, Cook County, Illinois
# 756  17031750600  60643   0.956550  Census Tract 7506, Cook County, Illinois
#
#      CommunityAreaNumber CommunityAreaName  non_preventable_em_percent_x  \
# 0                      1       Rogers Park                           NaN
# 1                      1       Rogers Park                        10.970
# 2                      1       Rogers Park                        10.970
# 3                      1       Rogers Park                        10.970
# 4                      1       Rogers Park                        11.755
# ..                   ...               ...                           ...
# 752                   75       Morgan Park                        11.170
# 753                   75       Morgan Park                        12.180
# 754                   75       Morgan Park                        11.170
# 755                   75       Morgan Park                        10.250
# 756                   75       Morgan Park                        11.170
#
#      avg_HA_readmission_per_100k  avg_HF_readmission_per_100k  \
# 0                            NaN                          NaN
# 1                      23.903333                    58.663333
# 2                      23.903333                    58.663333
# 3                      23.903333                    58.663333
# 4                      38.216667                    86.233333
# ..                           ...                          ...
# 752                    43.373333                   175.660000
# 753                          NaN                    74.703333
# 754                    43.373333                   175.660000
# 755                    60.360000                   211.486667
# 756                    43.373333                   175.660000
#
#      non_preventable_em_percent_y  avg_PN_readmission_per_100k  \
# 0                             NaN                          NaN
# 1                          10.970                    45.733333
# 2                          10.970                    45.733333
# 3                          10.970                    45.733333
# 4                          11.755                    28.160000
# ..                            ...                          ...
# 752                        11.170                    52.633333
# 753                        12.180                          NaN
# 754                        11.170                    52.633333
# 755                        10.250                    49.286667
# 756                        11.170                    52.633333
#
#      preventable_em_percent  avg_HA_readmission_per_100k_weighted  \
# 0                       NaN                                   NaN
# 1                    5.7200                             23.896162
# 2                    5.7200                             23.903333
# 3                    5.7200                             23.855335
# 4                    4.9300                              0.076740
# ..                      ...                                   ...
# 752                  6.3425                              4.697722
# 753                  4.0975                                   NaN
# 754                  6.3425                             43.373333
# 755                  7.5950                              2.622648
# 756                  6.3425                             41.488762
#
#      avg_HF_readmission_per_100k_weighted  \
# 0                                     NaN
# 1                               58.645734
# 2                               58.663333
# 3                               58.545537
# 4                                0.173159
# ..                                    ...
# 752                             19.025559
# 753                             66.612290
# 754                            175.660000
# 755                              9.189117
# 756                            168.027573
#
#      avg_PN_readmission_per_100k_weighted  \
# 0                                     NaN
# 1                               45.719613
# 2                               45.733333
# 3                               45.641501
# 4                                0.056546
# ..                                    ...
# 752                              5.700664
# 753                                   NaN
# 754                             52.633333
# 755                              2.141511
# 756                             50.346415
#
#      non_preventable_em_percent_x_weighted  preventable_em_percent_weighted
# 0                                      NaN                              NaN
# 1                                10.966709                         5.718284
# 2                                10.970000                         5.720000
# 3                                10.947972                         5.708514
# 4                                 0.023604                         0.009900
# ..                                     ...                              ...
# 752                               1.209812                         0.686950
# 753                              10.860796                         3.653704
# 754                              11.170000                         6.342500
# 755                               0.445364                         0.330004
# 756                              10.684663                         6.066918
#
# [757 rows x 17 columns]

# %%
# Group by Community Area
community_readmission = weighted_data.groupby(["CommunityAreaNumber", "CommunityAreaName"]).agg({
    "avg_HA_readmission_per_100k_weighted": "sum",
    "avg_HF_readmission_per_100k_weighted": "sum",
    "avg_PN_readmission_per_100k_weighted": "sum",
    "non_preventable_em_percent_x_weighted": "sum",
    "preventable_em_percent_weighted": "sum",
    "TOT_RATIO": "sum"  # Used for normalization
}).reset_index()

# Convert sums to weighted averages
for col in [
    "avg_HA_readmission_per_100k_weighted", 
    "avg_HF_readmission_per_100k_weighted", 
    "avg_PN_readmission_per_100k_weighted", 
    "non_preventable_em_percent_x_weighted", 
    "preventable_em_percent_weighted"
]:
    community_readmission[col] = community_readmission[col] / community_readmission["TOT_RATIO"]

# Rename columns for clarity
community_readmission.rename(columns={
    "avg_HA_readmission_per_100k_weighted": "HA_readmit_per_100k",
    "avg_HF_readmission_per_100k_weighted": "HF_readmit_per_100k",
    "avg_PN_readmission_per_100k_weighted": "PN_readmit_per_100k",
    "non_preventable_em_percent_x_weighted": "NonPreventable_readmit_pct",
    "preventable_em_percent_weighted": "Preventable_readmit_pct"
}, inplace=True)

# Drop TOT_RATIO as it is no longer needed
community_readmission = community_readmission.drop(columns=["TOT_RATIO"])

# %%
community_readmission
# Out:
#     CommunityAreaNumber   CommunityAreaName  HA_readmit_per_100k  \
# 0                     1         Rogers Park            23.929434
# 1                     2          West Ridge            40.979930
# 2                     3              Uptown            33.381359
# 3                     4      Lincoln Square            29.753350
# 4                     5        North Center            33.209274
# ..                  ...                 ...                  ...
# 69                   72             Beverly            32.052750
# 70                   73  Washington Heights            45.395734
# 71                   74     Mount Greenwood             0.000000
# 72                   75         Morgan Park            30.403794
# 73                   77           Edgewater            38.256285
#
#     HF_readmit_per_100k  PN_readmit_per_100k  NonPreventable_readmit_pct  \
# 0             58.712661            45.695651                   10.970706
# 1             82.588839            44.950413                   11.460243
# 2             71.612356            39.319865                   11.157251
# 3             57.172124            39.940210                   11.320239
# 4             65.029675            17.378078                   11.615685
# ..                  ...                  ...                         ...
# 69           149.346675            38.910664                   11.433137
# 70           187.284662            50.449703                   10.874660
# 71            74.750124             0.055270                   12.179975
# 72           145.429947            36.624483                   11.466093
# 73            81.859256            33.570578                   11.497213
#
#     Preventable_readmit_pct
# 0                  5.718031
# 1                  5.430824
# 2                  5.162442
# 3                  5.439591
# 4                  4.971361
# ..                      ...
# 69                 5.757955
# 70                 6.931355
# 71                 4.097915
# 72                 5.675410
# 73                 5.052067
#
# [74 rows x 7 columns]

# %% [markdown]
# ## Step 7: Integrating Readmission Data with the Existing Chicago Community Area Shapefile

# %%
import geopandas as gpd
community_areas = gpd.read_file("data/Chi-CCA/Chicago_2020.shp")
community_areas['area_numbe'] = community_areas['area_numbe'].astype(int)
community_areas.rename(columns = {'area_numbe': 'CommunityAreaNumber'}, inplace=True)
community_areas
# Out:
#     area_num_1  CommunityAreaNumber community    shape_area     shape_len  \
# 30         3.0                    3    UPTOWN  6.509564e+07  46972.794555
#
#     districtno   district  GEOID    GEOG  2000_POP  ...  KOREAN  OTHASIAN  \
# 30         1.0  Far North    3.0  Uptown   63551.0  ...   625.0    1833.0
#
#     OTHER_EURO  OTHUNSPEC  2000_WHITE  2000_HISP  2000_BLACK  2000_ASIAN  \
# 30      3456.0     3403.0     26784.0    12674.0     13415.0      8206.0
#
#     2000_OTHER                                           geometry
# 30      2472.0  POLYGON ((-87.64102 41.9548, -87.644 41.95465,...
#
# [1 rows x 217 columns]

# %%
community_readmission
# Out:
#     CommunityAreaNumber   CommunityAreaName  HA_readmit_per_100k  \
# 0                     1         Rogers Park            23.929434
# 1                     2          West Ridge            40.979930
# 2                     3              Uptown            33.381359
# 3                     4      Lincoln Square            29.753350
# 4                     5        North Center            33.209274
# ..                  ...                 ...                  ...
# 69                   72             Beverly            32.052750
# 70                   73  Washington Heights            45.395734
# 71                   74     Mount Greenwood             0.000000
# 72                   75         Morgan Park            30.403794
# 73                   77           Edgewater            38.256285
#
#     HF_readmit_per_100k  PN_readmit_per_100k  NonPreventable_readmit_pct  \
# 0             58.712661            45.695651                   10.970706
# 1             82.588839            44.950413                   11.460243
# 2             71.612356            39.319865                   11.157251
# 3             57.172124            39.940210                   11.320239
# 4             65.029675            17.378078                   11.615685
# ..                  ...                  ...                         ...
# 69           149.346675            38.910664                   11.433137
# 70           187.284662            50.449703                   10.874660
# 71            74.750124             0.055270                   12.179975
# 72           145.429947            36.624483                   11.466093
# 73            81.859256            33.570578                   11.497213
#
#     Preventable_readmit_pct
# 0                  5.718031
# 1                  5.430824
# 2                  5.162442
# 3                  5.439591
# 4                  4.971361
# ..                      ...
# 69                 5.757955
# 70                 6.931355
# 71                 4.097915
# 72                 5.675410
# 73                 5.052067
#
# [74 rows x 7 columns]

# %%
final_CA_df = community_areas.merge(community_readmission, on = "CommunityAreaNumber", how='left')

final_CA_df.to_file("/Users/michelangelopagan/Desktop/DATA/Data20519/Spatial Analysis RQ Data/CA_withparams/comm_areas_processed.shp")
# Out:
# /var/folders/wy/5tnkcj8n72sb4jfv_klmblj00000gn/T/ipykernel_13719/122140074.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   final_CA_df.to_file("/Users/michelangelopagan/Desktop/DATA/Data20519/Spatial Analysis RQ Data/CA_withparams/comm_areas_processed.shp")
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CommunityAreaNumber' to 'CommunityA'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'CommunityAreaName' to 'Communit_1'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'HA_readmit_per_100k' to 'HA_readmit'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'HF_readmit_per_100k' to 'HF_readmit'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'PN_readmit_per_100k' to 'PN_readmit'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'NonPreventable_readmit_pct' to 'NonPrevent'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Preventable_readmit_pct' to 'Preventabl'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 110196097.139 of field shape_area of feature 14 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 103595001.175 of field shape_area of feature 16 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 109099414.689 of field shape_area of feature 18 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 100057566.7 of field shape_area of feature 22 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 100480876.502 of field shape_area of feature 23 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 127562904.597 of field shape_area of feature 24 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 199254203.42699999 of field shape_area of feature 25 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 158492466.55399999 of field shape_area of feature 28 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 127998297.867 of field shape_area of feature 31 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 121959105.47 of field shape_area of feature 35 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 134313706.72999999 of field shape_area of feature 46 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 303797059.66000003 of field shape_area of feature 49 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 145965741.43700001 of field shape_area of feature 53 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 117890778.42900001 of field shape_area of feature 54 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 134636963.25400001 of field shape_area of feature 58 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 135460337.208 of field shape_area of feature 68 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 105065353.602 of field shape_area of feature 69 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 371835607.68699998 of field shape_area of feature 74 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(

# %% [markdown]
# ## Step 8: Creating Distance Metrics
# 1. `distance_to_academic` : The distance (in meters) to the nearest academic hopsital from the community area centroid.
# 2. `distance_to_nonacademic` : The distance (in meters) to the nearest non-academic hopsital from the community area centroid.

# %%
from shapely.geometry import Point
from geopandas.tools import sjoin
import geopandas as gpd

community_areas = gpd.read_file("CA_withparams/comm_areas_processed.shp")  # Polygon layer
academic_hospitals = gpd.read_file("Filtered/ChiAcademicHospitals.shp")  # Point layer
non_academic_hospitals = gpd.read_file("Filtered/ChiNonAcademicHospitals.shp")  # Point layer

print(community_areas.crs)
# Out:
# GEOGCS["unknown",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AXIS["Longitude",EAST],AXIS["Latitude",NORTH]]

# %%
community_areas["centroid"] = community_areas.geometry.centroid

# Find nearest academic hospital
community_areas["nearest_academic"] = community_areas["centroid"].apply(
    lambda x: academic_hospitals.distance(x).min()
)

# Find nearest non-academic hospital
community_areas["nearest_non_academic"] = community_areas["centroid"].apply(
    lambda x: non_academic_hospitals.distance(x).min()
)

# Save updated shapefile
#community_areas = community_areas.drop(columns=["centroid"])
#community_areas.to_file("CA_withparams/updated_community_areas.shp")
# Out:
# /var/folders/wy/5tnkcj8n72sb4jfv_klmblj00000gn/T/ipykernel_6042/4246057010.py:9: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   community_areas["centroid"] = community_areas.geometry.centroid
# /var/folders/wy/5tnkcj8n72sb4jfv_klmblj00000gn/T/ipykernel_6042/4246057010.py:23: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   community_areas.to_file("CA_withparams/updated_community_areas.shp")
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'nearest_academic' to 'nearest_ac'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'nearest_non_academic' to 'nearest_no'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 110196097.139 of field shape_area of feature 14 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 103595001.175 of field shape_area of feature 16 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 109099414.689 of field shape_area of feature 18 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 100057566.7 of field shape_area of feature 22 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 100480876.502 of field shape_area of feature 23 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 127562904.597 of field shape_area of feature 24 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 199254203.42699999 of field shape_area of feature 25 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 158492466.55399999 of field shape_area of feature 28 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 127998297.867 of field shape_area of feature 31 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 121959105.47 of field shape_area of feature 35 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 134313706.72999999 of field shape_area of feature 46 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 303797059.66000003 of field shape_area of feature 49 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 145965741.43700001 of field shape_area of feature 53 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 117890778.42900001 of field shape_area of feature 54 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 134636963.25400001 of field shape_area of feature 58 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 135460337.208 of field shape_area of feature 68 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 105065353.602 of field shape_area of feature 69 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 371835607.68699998 of field shape_area of feature 74 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(

# %%
import geopandas as gpd
from shapely.ops import nearest_points

community_areas = gpd.read_file("CA_withparams/comm_areas_processed.shp")  # Polygon layer
academic_hospitals = gpd.read_file("Filtered/ChiAcademicHospitals.shp")  # Point layer
non_academic_hospitals = gpd.read_file("Filtered/ChiNonAcademicHospitals.shp")  # Point layer

community_areas = community_areas.to_crs(epsg=32616)  # UTM Zone 16N (for Chicago)
academic_hospitals = academic_hospitals.to_crs(epsg=32616)
non_academic_hospitals = non_academic_hospitals.to_crs(epsg=32616)
# Out:
# GEOGCS["unknown",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AXIS["Longitude",EAST],AXIS["Latitude",NORTH]]
# EPSG:3857
# EPSG:3857

# %%
community_areas["centroid"] = community_areas.geometry.centroid

def nearest_geom(row, target_gdf):
    nearest = target_gdf.geometry.apply(lambda x: row.distance(x))
    return target_gdf.loc[nearest.idxmin(), "geometry"].distance(row)

community_areas["distance_to_academic"] = community_areas["centroid"].apply(
    lambda x: nearest_geom(x, academic_hospitals)
)
community_areas["distance_to_non_academic"] = community_areas["centroid"].apply(
    lambda x: nearest_geom(x, non_academic_hospitals)
)

# %%
community_areas = community_areas.drop(columns = ['centroid'])
community_areas.to_file("CA_withparams/updated_with_distance.shp")
# Out:
# /var/folders/wy/5tnkcj8n72sb4jfv_klmblj00000gn/T/ipykernel_7708/3383835735.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   community_areas.to_file("CA_withparams/updated_with_distance.shp")
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'distance_to_academic' to 'distance_t'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Normalized/laundered field name: 'distance_to_non_academic' to 'distance_1'
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 110196097.139 of field shape_area of feature 14 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 103595001.175 of field shape_area of feature 16 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 109099414.689 of field shape_area of feature 18 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 100057566.7 of field shape_area of feature 22 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 100480876.502 of field shape_area of feature 23 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 127562904.597 of field shape_area of feature 24 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 199254203.42699999 of field shape_area of feature 25 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 158492466.55399999 of field shape_area of feature 28 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 127998297.867 of field shape_area of feature 31 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 121959105.47 of field shape_area of feature 35 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 134313706.72999999 of field shape_area of feature 46 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 303797059.66000003 of field shape_area of feature 49 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 145965741.43700001 of field shape_area of feature 53 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 117890778.42900001 of field shape_area of feature 54 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 134636963.25400001 of field shape_area of feature 58 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 135460337.208 of field shape_area of feature 68 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 105065353.602 of field shape_area of feature 69 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(
# /Users/michelangelopagan/opt/anaconda3/envs/sp_clusters/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 371835607.68699998 of field shape_area of feature 74 not successfully written. Possibly due to too larger number with respect to field width
#   ogr_write(

# %%
community_areas.head(5)
# Out:
#    area_num_1  CommunityA        community    shape_area     shape_len  \
# 0        35.0          35          DOUGLAS  4.600462e+07  31027.054510
# 1        36.0          36          OAKLAND  1.691396e+07  19565.506153
# 2        37.0          37      FULLER PARK  1.991670e+07  25339.089750
# 3        38.0          38  GRAND BOULEVARD  4.849250e+07  28196.837157
# 4        39.0          39          KENWOOD  2.907174e+07  23325.167906
#
#    districtno    district  GEOID             GEOG  2000_POP  ...  CATEGORIES  \
# 0         7.0  South Side   35.0          Douglas   26470.0  ...         3.0
# 1         7.0  South Side   36.0          Oakland    6110.0  ...         3.0
# 2         7.0  South Side   37.0      Fuller Park    3420.0  ...         1.0
# 3         7.0  South Side   38.0  Grand Boulevard   28006.0  ...         2.0
# 4         7.0  South Side   39.0          Kenwood   18363.0  ...         2.0
#
#    card     cpval  Ac_Density  Hospi_ount  Centroid_X  Centroid_Y  \
# 0   2.0  0.030937         0.0         0.0  -87.618678   41.835118
# 1   0.0  0.000000         0.0         0.0  -87.603216   41.823750
# 2   0.0  0.000000         0.0         0.0  -87.632425   41.809085
# 3   2.0  0.030937         1.0         1.0  -87.617860   41.812949
# 4   2.0  0.030937         0.0         0.0  -87.596184   41.808916
#
#                                             geometry  distance_to_academic  \
# 0  POLYGON ((449429.813 4632712.182, 449429.135 4...           3629.450884
# 1  POLYGON ((450818.899 4629619.879, 450806.01 46...           2486.008507
# 2  POLYGON ((447763.097 4627972.082, 447763.324 4...           1738.993887
# 3  POLYGON ((449609.917 4629615.48, 449610.009 46...           1201.318651
# 4  POLYGON ((450818.899 4629619.879, 450819.11 46...           1583.556456
#
#    distance_to_non_academic
# 0               1327.708351
# 1               2983.833559
# 2               3408.857018
# 3               3780.450836
# 4               4074.022567
#
# [5 rows x 232 columns]
